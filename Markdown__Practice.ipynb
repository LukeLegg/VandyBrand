# %% [markdown]
# <a href="https://colab.research.google.com/github/LukeLegg/VandyBrand/blob/main/Markdown__Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is the practice text.
#
# **hello**
#
# ***Hello***
#
# ##Hello

# %% [markdown]
# # Markdown Practice in Jupyter

# %% [markdown]
# ### Sub-headings
# Lists (both ordered and unordered)
#
#
# *   Item 1
# *   Item 2
#
#
#
# Links (link to the official Markdown guide)[link text](https://colab.research.google.com/#)
#
# Images ![nissan-brand-logo-1200x938-1594842787.jpg](data:image/jpeg;base64,...)
#
#
# * ** Bold** and *italic* text

# %%
# Markdown Practice in Jupyter
